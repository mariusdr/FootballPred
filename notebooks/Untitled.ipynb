# %%
import numpy as np
import pandas as pd

# %matplotlib inline 
import matplotlib.pyplot as plt 

import sqlite3

import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from dataset.db_query import *

# %%
conn = sqlite3.connect("../data/database.sqlite")

# %%
teams = query_teams(conn)
# Out:
# INFO:root:got 1458 rows from db

# %%
lt = LeagueTag.GER
st = SeasonTag.S14_15

matches = query_matches(conn, lt, st)
# Out:
# INFO:root:got 306 rows (league: GER (id 7809), season: 2014/2015) from db

# %%
matches.head()
# Out:
#         date  country_id  league_id     season  match_api_id  \
# 0 2014-08-22        7809       7809  2014/2015       1732658
# 1 2014-08-23        7809       7809  2014/2015       1732668
# 2 2014-08-24        7809       7809  2014/2015       1732669
# 3 2014-08-23        7809       7809  2014/2015       1732670
# 4 2014-08-23        7809       7809  2014/2015       1732671
#
#    home_team_api_id  away_team_api_id  away_team_long_name  \
# 0              9823              8721        VfL Wolfsburg
# 1              9789              8178  Bayer 04 Leverkusen
# 2              9788             10269        VfB Stuttgart
# 3              8226              8406          FC Augsburg
# 4              9904             10189        FC Schalke 04
#
#         home_team_long_name away_team_short_name   ...   away_player_Y3  \
# 0          FC Bayern Munich                  WOL   ...                3
# 1         Borussia Dortmund                  LEV   ...                3
# ...

# %%
matches.columns
# Out:
# Index(['date', 'country_id', 'league_id', 'season', 'match_api_id',
#        'home_team_api_id', 'away_team_api_id', 'away_team_long_name',
#        'home_team_long_name', 'away_team_short_name', 'home_team_short_name',
#        'home_team_goal', 'away_team_goal', 'home_player_1', 'home_player_2',
#        'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6',
#        'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10',
#        'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3',
#        'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7',
#        'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11',
#        'home_player_X1', 'home_player_X2', 'home_player_X3', 'home_player_X4',
#        'home_player_X5', 'home_player_X6', 'home_player_X7', 'home_player_X8',
#        'home_player_X9', 'home_player_X10', 'home_player_X11',
#        'home_player_Y1', 'home_player_Y2', 'home_player_Y3', 'home_player_Y4',
# ...

# %%
tar = pd.Timestamp(2014, 9, 24)

print(tar)
# Out:
# 2014-09-24 00:00:00

# %%
lo = tar - pd.to_timedelta(14, unit="d")
hi = tar + pd.to_timedelta(0, unit="d")

print(lo)
print(hi)
# Out:
# 2014-09-10 00:00:00
# 2014-09-24 00:00:00

# %%
matches[ (lo < matches["date"]) & (matches["date"] <= hi) ]
# Out:
#           date  country_id  league_id     season  match_api_id  \
# 198 2014-09-13        7809       7809  2014/2015       1732729
# 199 2014-09-13        7809       7809  2014/2015       1732730
# 200 2014-09-12        7809       7809  2014/2015       1732731
# 201 2014-09-13        7809       7809  2014/2015       1732732
# 202 2014-09-13        7809       7809  2014/2015       1732733
# 203 2014-09-14        7809       7809  2014/2015       1732734
# 204 2014-09-13        7809       7809  2014/2015       1732735
# 205 2014-09-14        7809       7809  2014/2015       1732736
# 206 2014-09-13        7809       7809  2014/2015       1732737
# 252 2014-09-20        7809       7809  2014/2015       1732739
# 253 2014-09-21        7809       7809  2014/2015       1732740
# 254 2014-09-20        7809       7809  2014/2015       1732741
# 255 2014-09-20        7809       7809  2014/2015       1732742
# 256 2014-09-19        7809       7809  2014/2015       1732743
# ...
