# %%
import numpy as np
import pandas as pd

# %matplotlib inline 
import matplotlib.pyplot as plt 

import sqlite3

import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from dataset.db_query import *

# %%
conn = sqlite3.connect("../data/database.sqlite")

# %%
help(LeagueTag)
# Out:
# Help on class LeagueTag in module dataset.db_query:
#
# class LeagueTag(enum.Enum)
#  |  Enum value equals the primary key in the League table in the SQL database
#  |  for easier querying later ...
#  |
#  |  Method resolution order:
#  |      LeagueTag
#  |      enum.Enum
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  BEL = <LeagueTag.BEL: 1>
#  |
#  |  ENG = <LeagueTag.ENG: 1729>
#  |
#  |  FRA = <LeagueTag.FRA: 4769>
#  |
#  |  GER = <LeagueTag.GER: 7809>
#  |
#  |  ITA = <LeagueTag.ITA: 10257>
#  |
#  |  NET = <LeagueTag.NET: 13274>
#  |
#  |  POL = <LeagueTag.POL: 15722>
#  |
#  |  POR = <LeagueTag.POR: 17642>
#  |
#  |  SCO = <LeagueTag.SCO: 19694>
#  |
#  |  SPA = <LeagueTag.SPA: 21518>
#  |
#  |  SWI = <LeagueTag.SWI: 24558>
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.Enum:
#  |
#  |  name
#  |      The name of the Enum member.
#  |
#  |  value
#  |      The value of the Enum member.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.EnumMeta:
#  |
#  |  __members__
#  |      Returns a mapping of member name->value.
#  |
#  |      This mapping lists all enum members, including aliases. Note that this
#  |      is a read-only view of the internal mapping.

# %%
lt = LeagueTag.SWI
st = SeasonTag.S15_16


matches = query_matches(conn, lt, st)
# Out:
# INFO:root:got 180 rows (league: SWI (id 24558), season: 2015/2016) from db

# %%
A = matches.loc[:, ['home_player_1', 'home_player_2',
       'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6',
       'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10',
       'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3',
       'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7',
       'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11']]

# %%
A.isnull().sum()
# Out:
# home_player_1     7
# home_player_2     1
# home_player_3     0
# home_player_4     1
# home_player_5     3
# home_player_6     0
# home_player_7     0
# home_player_8     0
# home_player_9     0
# home_player_10    0
# home_player_11    0
# away_player_1     7
# away_player_2     2
# away_player_3     0
# away_player_4     0
# away_player_5     3
# away_player_6     2
# away_player_7     0
# away_player_8     0
# away_player_9     0
# away_player_10    0
# away_player_11    0
# dtype: int64

# %%
players = query_all_players(conn)
# Out:
# INFO:root:got 183978 rows from db

# %%
players.head()
# Out:
#         date  player_fifa_api_id  player_api_id         player_name  \
# 0 2016-02-18              218353         505942  Aaron Appindangoye
# 1 2015-11-19              218353         505942  Aaron Appindangoye
# 2 2015-09-21              218353         505942  Aaron Appindangoye
# 3 2015-03-20              218353         505942  Aaron Appindangoye
# 4 2007-02-22              218353         505942  Aaron Appindangoye
#
#    overall_rating  potential attacking_work_rate defensive_work_rate  \
# 0            67.0       71.0              medium              medium
# 1            67.0       71.0              medium              medium
# 2            62.0       66.0              medium              medium
# 3            61.0       65.0              medium              medium
# 4            61.0       65.0              medium              medium
#
#    crossing  finishing         ...           penalties  marking  \
# 0      49.0       44.0         ...                48.0     65.0
# 1      49.0       44.0         ...                48.0     65.0
# 2      49.0       44.0         ...                48.0     65.0
# 3      48.0       43.0         ...                47.0     62.0
# 4      48.0       43.0         ...                47.0     62.0
#
#    standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0             69.0            69.0        6.0         11.0        10.0
# 1             69.0            69.0        6.0         11.0        10.0
# 2             66.0            69.0        6.0         11.0        10.0
# 3             63.0            66.0        5.0         10.0         9.0
# 4             63.0            66.0        5.0         10.0         9.0
#
#    gk_positioning  gk_reflexes             birthday
# 0             8.0          8.0  1992-02-29 00:00:00
# 1             8.0          8.0  1992-02-29 00:00:00
# 2             8.0          8.0  1992-02-29 00:00:00
# 3             7.0          7.0  1992-02-29 00:00:00
# 4             7.0          7.0  1992-02-29 00:00:00
#
# [5 rows x 42 columns]

# %%
players.player_api_id.isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 183948    False
# 183949    False
# 183950    False
# 183951    False
# 183952    False
# 183953    False
# 183954    False
# 183955    False
# 183956    False
# 183957    False
# 183958    False
# 183959    False
# 183960    False
# 183961    False
# 183962    False
# 183963    False
# 183964    False
# 183965    False
# 183966    False
# 183967    False
# 183968    False
# 183969    False
# 183970    False
# 183971    False
# 183972    False
# 183973    False
# 183974    False
# 183975    False
# 183976    False
# 183977    False
# Name: player_api_id, Length: 183978, dtype: bool
